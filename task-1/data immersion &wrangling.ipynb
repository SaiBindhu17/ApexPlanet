# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\acer\Downloads\sample_sales_dataset.csv")

# %%
df.head()
# Out:
#    Customer_ID       Customer_Name  Gender       City     Category  \
# 0         1001        Sara Kennedy    Male    Chennai    Groceries
# 1         1002     Cassandra Mckay  Female     Mumbai  Electronics
# 2         1003        Shane Garcia  Female    Chennai    Furniture
# 3         1004       Pamela Bishop  Female     Mumbai    Groceries
# 4         1005  Jennifer Hernandez    Male  Hyderabad    Groceries
#
#    Order_Date    Sales     Cost  Quantity
# 0  2024-11-12  1595.65   935.47         5
# 1  2026-01-14  3855.70  2428.94         1
# 2  2026-03-13   574.29   499.16         5
# 3  2025-06-06  1100.29   976.66         2
# 4  2025-10-03  1460.35   909.32         6

# %%
df.columns
# Out:
# Index(['Customer_ID', 'Customer_Name', 'Gender', 'City', 'Category',
#        'Order_Date', 'Sales', 'Cost', 'Quantity'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202 entries, 0 to 201
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Customer_ID    202 non-null    int64
#  1   Customer_Name  201 non-null    object
#  2   Gender         202 non-null    object
#  3   City           202 non-null    object
#  4   Category       202 non-null    object
#  5   Order_Date     202 non-null    object
#  6   Sales          201 non-null    float64
#  7   Cost           202 non-null    float64
#  8   Quantity       202 non-null    int64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 14.3+ KB

# %%
df.isnull().sum()
# Out:
# Customer_ID      0
# Customer_Name    1
# Gender           0
# City             0
# Category         0
# Order_Date       0
# Sales            1
# Cost             0
# Quantity         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(2)

# %%
df.isnull().sum()
# Out:
# Customer_ID      0
# Customer_Name    1
# Gender           0
# City             0
# Category         0
# Order_Date       0
# Sales            1
# Cost             0
# Quantity         0
# dtype: int64

# %%
df.fillna("Unknown", inplace=True)

# %%
df.fillna(0, inplace=True)

# %%
df.drop_duplicates(inplace=True)

# %%
df['Order_Date'] = pd.to_datetime(df['Order_Date'])

# %%
df['Gender'] = df['Gender'].str.upper()

# %%
df['Customer_Name'] = df['Customer_Name'].str.strip()

# %%
df['Year'] = df['Order_Date'].dt.year

# %%
df['Month'] = df['Order_Date'].dt.month_name()

# %%
df.to_csv("cleaned_data.csv", index=False)
